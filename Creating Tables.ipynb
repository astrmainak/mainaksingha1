# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
from scipy.optimize import curve_fit
from numpy import exp
from scipy import ndimage
from muse import *
from astropy.table import Table, hstack
import os
import glob
from astropy.table import Table, vstack, join
import pandas as pd
from shutil import copyfile

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print ('%s'%(obj))
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "HbOIII.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_HbOIII.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])
 #########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print infiles
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*HbOIII.fits',output_filename='flux_amp_table.fits')
# Out:
#   File "<ipython-input-2-fae76a19b486>", line 32
#     print infiles
#                 ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(infiles)?

# %%
def script3(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print '%s'%(obj)
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "9_arcsec_fluxden_HbOIII.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_9_arcsec_fluxden_HbOIII.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script3(obj,z[obj])
    
def script4(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print infiles
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script4(input_filename='./*9_arcsec_fluxden_HbOIII.fits',output_filename='Flux Amplitude Table 9 arcsec.fits')
# Out:
# HE0345+0056
# HE0412-0803
# HE0224-2834
# HE0433-1028
# HE2233+0124
# HE1330-1013
# HE1011-0403
# HE0429-0247
# HE0021-1810
# HE0227-0913
# HE1029-1831
# HE0232-0900
# HE2222-0026
# HE2302-0857
# HE0021-1819
# HE2128-0221
# HE0853+0102
# HE1237-0504
# HE1107-0813
# HE0114-0015
# HE2211-3903
# HE0351+0240
# HE0040-1105
# HE0253-1641
# HE1126-0407
# HE0119-0118
# HE1248-1356
# HE0108-4743
# HE1353-1917
# HE1417-0909
# HE0212-0059
# HE1108-2813
# HE0934+0119
# HE1017-0305
# ['./HE0021-1810_9_arcsec_fluxden_HbOIII.fits', './HE0021-1819_9_arcsec_fluxden_HbOIII.fits', './HE0040-1105_9_arcsec_fluxden_HbOIII.fits', './HE0108-4743_9_arcsec_fluxden_HbOIII.fits', './HE0114-0015_9_arcsec_fluxden_HbOIII.fits', './HE0119-0118_9_arcsec_fluxden_HbOIII.fits', './HE0212-0059_9_arcsec_fluxden_HbOIII.fits', './HE0224-2834_9_arcsec_fluxden_HbOIII.fits', './HE0227-0913_9_arcsec_fluxden_HbOIII.fits', './HE0232-0900_9_arcsec_fluxden_HbOIII.fits', './HE0253-1641_9_arcsec_fluxden_HbOIII.fits', './HE0345+0056_9_arcsec_fluxden_HbOIII.fits', './HE0351+0240_9_arcsec_fluxden_HbOIII.fits', './HE0412-0803_9_arcsec_fluxden_HbOIII.fits', './HE0429-0247_9_arcsec_fluxden_HbOIII.fits', './HE0433-1028_9_arcsec_fluxden_HbOIII.fits', './HE0853+0102_9_arcsec_fluxden_HbOIII.fits', './HE0934+0119_9_arcsec_fluxden_HbOIII.fits', './HE1011-0403_9_arcsec_fluxden_HbOIII.fits', './HE1017-0305_9_arcsec_fluxden_HbOIII.fits', './HE1029-1831_9_arcsec_fluxden_HbOIII.fits', './HE1107-0813_9_arcsec_fluxden_HbOIII.fits', './HE1108-2813_9_arcsec_fluxden_HbOIII.fits', './HE1126-0407_9_arcsec_fluxden_HbOIII.fits', './HE1237-0504_9_arcsec_fluxden_HbOIII.fits', './HE1248-1356_9_arcsec_fluxden_HbOIII.fits', './HE1330-1013_9_arcsec_fluxden_HbOIII.fits', './HE1353-1917_9_arcsec_fluxden_HbOIII.fits', './HE1417-0909_9_arcsec_fluxden_HbOIII.fits', './HE2128-0221_9_arcsec_fluxden_HbOIII.fits', './HE2211-3903_9_arcsec_fluxden_HbOIII.fits', './HE2222-0026_9_arcsec_fluxden_HbOIII.fits', './HE2233+0124_9_arcsec_fluxden_HbOIII.fits', './HE2302-0857_9_arcsec_fluxden_HbOIII.fits']

# %%
def script3(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print '%s'%(obj)
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "9_arcsec_chisq_tab_fluxden.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_9_arcsec_chisq_tab_fluxden.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script3(obj,z[obj])
    
def script4(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print infiles
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script4(input_filename='./*9_arcsec_chisq_tab_fluxden.fits',output_filename='ChiSq Table Flux Densities 9 arcsec.fits')
# Out:
# HE0345+0056
# HE0412-0803
# HE0224-2834
# HE0433-1028
# HE2233+0124
# HE1330-1013
# HE1011-0403
# HE0429-0247
# HE0021-1810
# HE0227-0913
# HE1029-1831
# HE0232-0900
# HE2222-0026
# HE2302-0857
# HE0021-1819
# HE2128-0221
# HE0853+0102
# HE1237-0504
# HE1107-0813
# HE0114-0015
# HE2211-3903
# HE0351+0240
# HE0040-1105
# HE0253-1641
# HE1126-0407
# HE0119-0118
# HE1248-1356
# HE0108-4743
# HE1353-1917
# HE1417-0909
# HE0212-0059
# HE1108-2813
# HE0934+0119
# HE1017-0305
# ['./HE0021-1810_9_arcsec_chisq_tab_fluxden.fits', './HE0021-1819_9_arcsec_chisq_tab_fluxden.fits', './HE0040-1105_9_arcsec_chisq_tab_fluxden.fits', './HE0108-4743_9_arcsec_chisq_tab_fluxden.fits', './HE0114-0015_9_arcsec_chisq_tab_fluxden.fits', './HE0119-0118_9_arcsec_chisq_tab_fluxden.fits', './HE0212-0059_9_arcsec_chisq_tab_fluxden.fits', './HE0224-2834_9_arcsec_chisq_tab_fluxden.fits', './HE0227-0913_9_arcsec_chisq_tab_fluxden.fits', './HE0232-0900_9_arcsec_chisq_tab_fluxden.fits', './HE0253-1641_9_arcsec_chisq_tab_fluxden.fits', './HE0345+0056_9_arcsec_chisq_tab_fluxden.fits', './HE0351+0240_9_arcsec_chisq_tab_fluxden.fits', './HE0412-0803_9_arcsec_chisq_tab_fluxden.fits', './HE0429-0247_9_arcsec_chisq_tab_fluxden.fits', './HE0433-1028_9_arcsec_chisq_tab_fluxden.fits', './HE0853+0102_9_arcsec_chisq_tab_fluxden.fits', './HE0934+0119_9_arcsec_chisq_tab_fluxden.fits', './HE1011-0403_9_arcsec_chisq_tab_fluxden.fits', './HE1017-0305_9_arcsec_chisq_tab_fluxden.fits', './HE1029-1831_9_arcsec_chisq_tab_fluxden.fits', './HE1107-0813_9_arcsec_chisq_tab_fluxden.fits', './HE1108-2813_9_arcsec_chisq_tab_fluxden.fits', './HE1126-0407_9_arcsec_chisq_tab_fluxden.fits', './HE1237-0504_9_arcsec_chisq_tab_fluxden.fits', './HE1248-1356_9_arcsec_chisq_tab_fluxden.fits', './HE1330-1013_9_arcsec_chisq_tab_fluxden.fits', './HE1353-1917_9_arcsec_chisq_tab_fluxden.fits', './HE1417-0909_9_arcsec_chisq_tab_fluxden.fits', './HE2128-0221_9_arcsec_chisq_tab_fluxden.fits', './HE2211-3903_9_arcsec_chisq_tab_fluxden.fits', './HE2222-0026_9_arcsec_chisq_tab_fluxden.fits', './HE2233+0124_9_arcsec_chisq_tab_fluxden.fits', './HE2302-0857_9_arcsec_chisq_tab_fluxden.fits']

# %%
def script5(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print '%s'%(obj)
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "flux.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_chisq_tab_flux.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script5(obj,z[obj])
# Out:
# HE0345+0056
# HE0412-0803
# HE0224-2834
# HE0433-1028
# HE2233+0124
# HE1330-1013
# HE1011-0403
# HE0429-0247
# HE0021-1810
# HE0227-0913
# HE1029-1831
# HE0232-0900
# HE2222-0026
# HE2302-0857
# HE0021-1819
# HE2128-0221
# HE0853+0102
# HE1237-0504
# HE1107-0813
# HE0114-0015
# HE2211-3903
# HE0351+0240
# HE0040-1105
# HE0253-1641
# HE1126-0407
# HE0119-0118
# HE1248-1356
# HE0108-4743
# HE1353-1917
# HE1417-0909
# HE0212-0059
# HE1108-2813
# HE0934+0119
# HE1017-0305

# %%
def script(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print infiles
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script(input_filename='./*tab_flux.fits',output_filename='chisq_flux_table.fits')
# Out:
# ['./HE0021-1810_chisq_tab_flux.fits', './HE0021-1819_chisq_tab_flux.fits', './HE0040-1105_chisq_tab_flux.fits', './HE0108-4743_chisq_tab_flux.fits', './HE0114-0015_chisq_tab_flux.fits', './HE0119-0118_chisq_tab_flux.fits', './HE0212-0059_chisq_tab_flux.fits', './HE0224-2834_chisq_tab_flux.fits', './HE0227-0913_chisq_tab_flux.fits', './HE0232-0900_chisq_tab_flux.fits', './HE0253-1641_chisq_tab_flux.fits', './HE0345+0056_chisq_tab_flux.fits', './HE0351+0240_chisq_tab_flux.fits', './HE0412-0803_chisq_tab_flux.fits', './HE0429-0247_chisq_tab_flux.fits', './HE0433-1028_chisq_tab_flux.fits', './HE0853+0102_chisq_tab_flux.fits', './HE0934+0119_chisq_tab_flux.fits', './HE1011-0403_chisq_tab_flux.fits', './HE1017-0305_chisq_tab_flux.fits', './HE1029-1831_chisq_tab_flux.fits', './HE1107-0813_chisq_tab_flux.fits', './HE1108-2813_chisq_tab_flux.fits', './HE1126-0407_chisq_tab_flux.fits', './HE1237-0504_chisq_tab_flux.fits', './HE1248-1356_chisq_tab_flux.fits', './HE1330-1013_chisq_tab_flux.fits', './HE1353-1917_chisq_tab_flux.fits', './HE1417-0909_chisq_tab_flux.fits', './HE2128-0221_chisq_tab_flux.fits', './HE2211-3903_chisq_tab_flux.fits', './HE2222-0026_chisq_tab_flux.fits', './HE2233+0124_chisq_tab_flux.fits', './HE2302-0857_chisq_tab_flux.fits']

# %%
def script(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print '%s'%(obj)
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "fluxden.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_chisq_tab_fluxden.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script(obj,z[obj])
# Out:
# HE0345+0056
# HE0412-0803
# HE0224-2834
# HE0433-1028
# HE2233+0124
# HE1330-1013
# HE1011-0403
# HE0429-0247
# HE0021-1810
# HE0227-0913
# HE1029-1831
# HE0232-0900
# HE2222-0026
# HE2302-0857
# HE0021-1819
# HE2128-0221
# HE0853+0102
# HE1237-0504
# HE1107-0813
# HE0114-0015
# HE2211-3903
# HE0351+0240
# HE0040-1105
# HE0253-1641
# HE1126-0407
# HE0119-0118
# HE1248-1356
# HE0108-4743
# HE1353-1917
# HE1417-0909
# HE0212-0059
# HE1108-2813
# HE0934+0119
# HE1017-0305

# %%
def script(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print infiles
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script(input_filename='./*tab_fluxden.fits',output_filename='chisq_fluxden_table.fits')
# Out:
# ['./HE0021-1810_chisq_tab_fluxden.fits', './HE0021-1819_chisq_tab_fluxden.fits', './HE0040-1105_chisq_tab_fluxden.fits', './HE0108-4743_chisq_tab_fluxden.fits', './HE0114-0015_chisq_tab_fluxden.fits', './HE0119-0118_chisq_tab_fluxden.fits', './HE0212-0059_chisq_tab_fluxden.fits', './HE0224-2834_chisq_tab_fluxden.fits', './HE0227-0913_chisq_tab_fluxden.fits', './HE0232-0900_chisq_tab_fluxden.fits', './HE0253-1641_chisq_tab_fluxden.fits', './HE0345+0056_chisq_tab_fluxden.fits', './HE0351+0240_chisq_tab_fluxden.fits', './HE0412-0803_chisq_tab_fluxden.fits', './HE0429-0247_chisq_tab_fluxden.fits', './HE0433-1028_chisq_tab_fluxden.fits', './HE0853+0102_chisq_tab_fluxden.fits', './HE0934+0119_chisq_tab_fluxden.fits', './HE1011-0403_chisq_tab_fluxden.fits', './HE1017-0305_chisq_tab_fluxden.fits', './HE1029-1831_chisq_tab_fluxden.fits', './HE1107-0813_chisq_tab_fluxden.fits', './HE1108-2813_chisq_tab_fluxden.fits', './HE1126-0407_chisq_tab_fluxden.fits', './HE1237-0504_chisq_tab_fluxden.fits', './HE1248-1356_chisq_tab_fluxden.fits', './HE1330-1013_chisq_tab_fluxden.fits', './HE1353-1917_chisq_tab_fluxden.fits', './HE1417-0909_chisq_tab_fluxden.fits', './HE2128-0221_chisq_tab_fluxden.fits', './HE2211-3903_chisq_tab_fluxden.fits', './HE2222-0026_chisq_tab_fluxden.fits', './HE2233+0124_chisq_tab_fluxden.fits', './HE2302-0857_chisq_tab_fluxden.fits']

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print '%s'%(obj)
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "9_arcsec_empirical_factor_subcube.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_9_arcsec_empirical_factor_subcube.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])
 #########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print infiles
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*9_arcsec_empirical_factor_subcube.fits',output_filename='Empirical Factor Table.fits')
# Out:
# HE0345+0056
# HE0412-0803
# HE0224-2834
# HE0433-1028
# HE2233+0124
# HE1330-1013
# HE1011-0403
# HE0429-0247
# HE0021-1810
# HE0227-0913
# HE1029-1831
# HE0232-0900
# HE2222-0026
# HE2302-0857
# HE0021-1819
# HE2128-0221
# HE0853+0102
# HE1237-0504
# HE1107-0813
# HE0114-0015
# HE2211-3903
# HE0351+0240
# HE0040-1105
# HE0253-1641
# HE1126-0407
# HE0119-0118
# HE1248-1356
# HE0108-4743
# HE1353-1917
# HE1417-0909
# HE0212-0059
# ['./HE0021-1810_offsettable.fits', './HE0021-1819_offsettable.fits', './HE0040-1105_offsettable.fits', './HE0108-4743_offsettable.fits', './HE0114-0015_offsettable.fits', './HE0119-0118_offsettable.fits', './HE0212-0059_offsettable.fits', './HE0224-2834_offsettable.fits', './HE0227-0913_offsettable.fits', './HE0232-0900_offsettable.fits', './HE0253-1641_offsettable.fits', './HE0345+0056_offsettable.fits', './HE0351+0240_offsettable.fits', './HE0412-0803_offsettable.fits', './HE0429-0247_offsettable.fits', './HE0433-1028_offsettable.fits', './HE0853+0102_offsettable.fits', './HE0934+0119_offsettable.fits', './HE1011-0403_offsettable.fits', './HE1017-0305_offsettable.fits', './HE1029-1831_offsettable.fits', './HE1107-0813_offsettable.fits', './HE1108-2813_offsettable.fits', './HE1126-0407_offsettable.fits', './HE1237-0504_offsettable.fits', './HE1248-1356_offsettable.fits', './HE1330-1013_offsettable.fits', './HE1353-1917_offsettable.fits', './HE1417-0909_offsettable.fits', './HE2128-0221_offsettable.fits', './HE2211-3903_offsettable.fits', './HE2222-0026_offsettable.fits', './HE2233+0124_offsettable.fits', './HE2302-0857_offsettable.fits']

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print '%s'%(obj)
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "fluxdensity.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_fluxdensity.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])
 #########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print infiles
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
#script2(input_filename='./*fluxdensity.fits',output_filename='fluxdensity.fits')
# Out:
# HE0345+0056
# HE0412-0803
# HE0224-2834
# HE0433-1028
# HE2233+0124
# HE1330-1013
# HE1011-0403
# HE0429-0247
# HE0021-1810
# HE0227-0913
# HE1029-1831
# HE0232-0900
# HE2222-0026
# HE2302-0857
# HE0021-1819
# HE2128-0221
# HE0853+0102
# HE1237-0504
# HE1107-0813
# HE0114-0015
# HE2211-3903
# HE0351+0240
# HE0040-1105
# HE0253-1641
# HE1126-0407
# HE0119-0118
# HE1248-1356
# HE0108-4743
# HE1353-1917
# HE1417-0909
# HE0212-0059
# HE1108-2813
# HE0934+0119
# HE1017-0305

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "chisqaured3.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_chisqaured3.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*chisqaured3.fits',output_filename='3 arcsec chisq and flux ratio.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "fluxdensity3.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_fluxdensity3.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*fluxdensity3.fits',output_filename='3 arcsec fixkin flux density.fits')

# %%
def script1(obj,z,prefix_path_cube="/home/rickeythecat/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "fluxdensity4.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_fluxdensity4.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/rickeythecat/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*fluxdensity4.fits',output_filename='3 arcsec psf [OIII] br flux density.fits')

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "alternative.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_parameters_err_alternative.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*alternative.fits',output_filename='Error with Parameters.fits')

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "nucleartab.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_nucleartab.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*nucleartab.fits',output_filename='QSO Spectral Parameters Mainak.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810_nucleartab.fits', './HE0021-1819_nucleartab.fits', './HE0040-1105_nucleartab.fits', './HE0108-4743_nucleartab.fits', './HE0114-0015_nucleartab.fits', './HE0119-0118_nucleartab.fits', './HE0212-0059_nucleartab.fits', './HE0224-2834_nucleartab.fits', './HE0227-0913_nucleartab.fits', './HE0232-0900_nucleartab.fits', './HE0253-1641_nucleartab.fits', './HE0345+0056_nucleartab.fits', './HE0351+0240_nucleartab.fits', './HE0412-0803_nucleartab.fits', './HE0429-0247_nucleartab.fits', './HE0433-1028_nucleartab.fits', './HE0853+0102_nucleartab.fits', './HE0934+0119_nucleartab.fits', './HE1011-0403_nucleartab.fits', './HE1017-0305_nucleartab.fits', './HE1029-1831_nucleartab.fits', './HE1107-0813_nucleartab.fits', './HE1108-2813_nucleartab.fits', './HE1126-0407_nucleartab.fits', './HE1237-0504_nucleartab.fits', './HE1248-1356_nucleartab.fits', './HE1330-1013_nucleartab.fits', './HE1353-1917_nucleartab.fits', './HE1417-0909_nucleartab.fits', './HE2128-0221_nucleartab.fits', './HE2211-3903_nucleartab.fits', './HE2222-0026_nucleartab.fits', './HE2233+0124_nucleartab.fits', './HE2302-0857_nucleartab.fits']

# %%
def script3(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print ('%s'%(obj))
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "3_arcsec_fluxden_HbOIII.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_3_arcsec_fluxden_HbOIII.fits'%(prefix_path_cube,obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script3(obj,z[obj])
    
def script4(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script4(input_filename='./*3_arcsec_fluxden_HbOIII.fits',output_filename='Flux Amplitude Table 3 arcsec.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b9f2991b4c9c> in <module>
#      45     dtab.write(output_filename, format='fits', overwrite=True)
#      46
# ---> 47 script4(input_filename='./*3_arcsec_fluxden_HbOIII.fits',output_filename='Flux Amplitude Table 3 arcsec.fits')
#
# <ipython-input-6-b9f2991b4c9c> in script4(input_filename, output_filename, destination_path_cube)
#      36         bintab = hdulist[1].data
#      37         table = Table(bintab)
# ---> 38         name = table['Source'][0]
#      39         tabledict[name] = table
#      40
#
# ~/anaconda2/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1344     def __getitem__(self, item):
#    1345         if isinstance(item, str):
# -> 1346             return self.columns[item]
#    1347         elif isinstance(item, (int, np.integer)):
#    1348             return self.Row(self, item)
#
# ~/anaconda2/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#     188         """
#     189         if isinstance(item, str):
# --> 190             return OrderedDict.__getitem__(self, item)
#     191         elif isinstance(item, (int, np.integer)):
#     192             return self.values()[item]
#
# KeyError: 'Source'

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "fixkin_central_tab.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s.kinpar_fixkin_central_tab.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*fixkin_central_tab.fits',output_filename='CARS Kinematic Parameters.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810.kinpar_fixkin_central_tab.fits', './HE0021-1819.kinpar_fixkin_central_tab.fits', './HE0040-1105.kinpar_fixkin_central_tab.fits', './HE0108-4743.kinpar_fixkin_central_tab.fits', './HE0114-0015.kinpar_fixkin_central_tab.fits', './HE0119-0118.kinpar_fixkin_central_tab.fits', './HE0212-0059.kinpar_fixkin_central_tab.fits', './HE0224-2834.kinpar_fixkin_central_tab.fits', './HE0227-0913.kinpar_fixkin_central_tab.fits', './HE0232-0900.kinpar_fixkin_central_tab.fits', './HE0253-1641.kinpar_fixkin_central_tab.fits', './HE0345+0056.kinpar_fixkin_central_tab.fits', './HE0351+0240.kinpar_fixkin_central_tab.fits', './HE0412-0803.kinpar_fixkin_central_tab.fits', './HE0429-0247.kinpar_fixkin_central_tab.fits', './HE0433-1028.kinpar_fixkin_central_tab.fits', './HE0853+0102.kinpar_fixkin_central_tab.fits', './HE0934+0119.kinpar_fixkin_central_tab.fits', './HE1011-0403.kinpar_fixkin_central_tab.fits', './HE1017-0305.kinpar_fixkin_central_tab.fits', './HE1029-1831.kinpar_fixkin_central_tab.fits', './HE1107-0813.kinpar_fixkin_central_tab.fits', './HE1108-2813.kinpar_fixkin_central_tab.fits', './HE1126-0407.kinpar_fixkin_central_tab.fits', './HE1237-0504.kinpar_fixkin_central_tab.fits', './HE1248-1356.kinpar_fixkin_central_tab.fits', './HE1330-1013.kinpar_fixkin_central_tab.fits', './HE1353-1917.kinpar_fixkin_central_tab.fits', './HE1417-0909.kinpar_fixkin_central_tab.fits', './HE2128-0221.kinpar_fixkin_central_tab.fits', './HE2211-3903.kinpar_fixkin_central_tab.fits', './HE2222-0026.kinpar_fixkin_central_tab.fits', './HE2233+0124.kinpar_fixkin_central_tab.fits', './HE2302-0857.kinpar_fixkin_central_tab.fits']

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "agncentral_fit.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_agncentral_fit.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*agncentral_fit.fits',output_filename='CARS AGN Spectral Parameters.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810_agncentral_fit.fits', './HE0021-1819_agncentral_fit.fits', './HE0040-1105_agncentral_fit.fits', './HE0108-4743_agncentral_fit.fits', './HE0114-0015_agncentral_fit.fits', './HE0119-0118_agncentral_fit.fits', './HE0212-0059_agncentral_fit.fits', './HE0224-2834_agncentral_fit.fits', './HE0227-0913_agncentral_fit.fits', './HE0232-0900_agncentral_fit.fits', './HE0253-1641_agncentral_fit.fits', './HE0345+0056_agncentral_fit.fits', './HE0351+0240_agncentral_fit.fits', './HE0412-0803_agncentral_fit.fits', './HE0429-0247_agncentral_fit.fits', './HE0433-1028_agncentral_fit.fits', './HE0853+0102_agncentral_fit.fits', './HE0934+0119_agncentral_fit.fits', './HE1011-0403_agncentral_fit.fits', './HE1017-0305_agncentral_fit.fits', './HE1029-1831_agncentral_fit.fits', './HE1107-0813_agncentral_fit.fits', './HE1108-2813_agncentral_fit.fits', './HE1126-0407_agncentral_fit.fits', './HE1237-0504_agncentral_fit.fits', './HE1248-1356_agncentral_fit.fits', './HE1330-1013_agncentral_fit.fits', './HE1353-1917_agncentral_fit.fits', './HE1417-0909_agncentral_fit.fits', './HE2128-0221_agncentral_fit.fits', './HE2211-3903_agncentral_fit.fits', './HE2222-0026_agncentral_fit.fits', './HE2233+0124_agncentral_fit.fits', './HE2302-0857_agncentral_fit.fits']

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "fixkin_kinparerr.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s.fixkin_kinparerr.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*fixkin_kinparerr.fits',output_filename='CARS Kinematic Parameters Error.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810.fixkin_kinparerr.fits', './HE0021-1819.fixkin_kinparerr.fits', './HE0040-1105.fixkin_kinparerr.fits', './HE0108-4743.fixkin_kinparerr.fits', './HE0114-0015.fixkin_kinparerr.fits', './HE0119-0118.fixkin_kinparerr.fits', './HE0212-0059.fixkin_kinparerr.fits', './HE0224-2834.fixkin_kinparerr.fits', './HE0227-0913.fixkin_kinparerr.fits', './HE0232-0900.fixkin_kinparerr.fits', './HE0253-1641.fixkin_kinparerr.fits', './HE0345+0056.fixkin_kinparerr.fits', './HE0351+0240.fixkin_kinparerr.fits', './HE0412-0803.fixkin_kinparerr.fits', './HE0429-0247.fixkin_kinparerr.fits', './H
fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/MUSE Systematic Error New/%s_syst_errtab.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE/MUSE Systematic Error New"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*errtab.fits',output_filename = 'MUSE Systematic Error Values.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810_syst_errtab.fits', './HE0021-1819_syst_errtab.fits', './HE0040-1105_syst_errtab.fits', './HE0108-4743_syst_errtab.fits', './HE0114-0015_syst_errtab.fits', './HE0119-0118_syst_errtab.fits', './HE0212-0059_syst_errtab.fits', './HE0224-2834_syst_errtab.fits', './HE0227-0913_syst_errtab.fits', './HE0232-0900_syst_errtab.fits', './HE0253-1641_syst_errtab.fits', './HE0345+0056_syst_errtab.fits', './HE0351+0240_syst_errtab.fits', './HE0412-0803_syst_errtab.fits', './HE0429-0247_syst_errtab.fits', './HE0433-1028_syst_errtab.fits', './HE0853+0102_syst_errtab.fits', './HE0934+0119_syst_errtab.fits', './HE1011-0403_syst_errtab.fits', './HE1017-0305_syst_errtab.fits', './HE1029-1831_syst_errtab.fits', './HE1107-0813_syst_errtab.fits', './HE1108-2813_syst_errtab.fits', './HE1126-0407_syst_errtab.fits', './HE1237-0504_syst_errtab.fits', './HE1248-1356_syst_errtab.fits', './HE1330-1013_syst_errtab.fits', './HE1353-1917_syst_errtab.fits', './HE1417-0909_syst_errtab.fits', './HE2128-0221_syst_errtab.fits', './HE2211-3903_syst_errtab.fits', './HE2222-0026_syst_errtab.fits', './HE2233+0124_syst_errtab.fits', './HE2302-0857_syst_errtab.fits']

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "offsettable.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_offsettable.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*offsettable.fits',output_filename='MUSE spatial offsets.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810_offsettable.fits', './HE0021-1819_offsettable.fits', './HE0040-1105_offsettable.fits', './HE0108-4743_offsettable.fits', './HE0114-0015_offsettable.fits', './HE0119-0118_offsettable.fits', './HE0212-0059_offsettable.fits', './HE0224-2834_offsettable.fits', './HE0227-0913_offsettable.fits', './HE0232-0900_offsettable.fits', './HE0253-1641_offsettable.fits', './HE0345+0056_offsettable.fits', './HE0351+0240_offsettable.fits', './HE0412-0803_offsettable.fits', './HE0429-0247_offsettable.fits', './HE0433-1028_offsettable.fits', './HE0853+0102_offsettable.fits', './HE0934+0119_offsettable.fits', './HE1011-0403_offsettable.fits', './HE1017-0305_offsettable.fits', './HE1029-1831_offsettable.fits', './HE1107-0813_offsettable.fits', './HE1108-2813_offsettable.fits', './HE1126-0407_offsettable.fits', './HE1237-0504_offsettable.fits', './HE1330-1013_offsettable.fits', './HE1353-1917_offsettable.fits', './HE1417-0909_offsettable.fits', './HE2128-0221_offsettable.fits', './HE2211-3903_offsettable.fits', './HE2222-0026_offsettable.fits', './HE2233+0124_offsettable.fits', './HE2302-0857_offsettable.fits']

# %%
def script1(obj,z,prefix_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "moffat_table.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_moffat_table.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*moffat_table.fits',output_filename='MUSE moffat table.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810_moffat_table.fits', './HE0021-1819_moffat_table.fits', './HE0040-1105_moffat_table.fits', './HE0108-4743_moffat_table.fits', './HE0114-0015_moffat_table.fits', './HE0119-0118_moffat_table.fits', './HE0212-0059_moffat_table.fits', './HE0224-2834_moffat_table.fits', './HE0227-0913_moffat_table.fits', './HE0232-0900_moffat_table.fits', './HE0253-1641_moffat_table.fits', './HE0345+0056_moffat_table.fits', './HE0351+0240_moffat_table.fits', './HE0412-0803_moffat_table.fits', './HE0429-0247_moffat_table.fits', './HE0433-1028_moffat_table.fits', './HE0853+0102_moffat_table.fits', './HE0934+0119_moffat_table.fits', './HE1011-0403_moffat_table.fits', './HE1017-0305_moffat_table.fits', './HE1029-1831_moffat_table.fits', './HE1107-0813_moffat_table.fits', './HE1108-2813_moffat_table.fits', './HE1126-0407_moffat_table.fits', './HE1237-0504_moffat_table.fits', './HE1248-1356_moffat_table.fits', './HE1330-1013_moffat_table.fits', './HE1353-1917_moffat_table.fits', './HE1417-0909_moffat_table.fits', './HE2128-0221_moffat_table.fits', './HE2211-3903_moffat_table.fits', './HE2222-0026_moffat_table.fits', './HE2233+0124_moffat_table.fits', './HE2302-0857_moffat_table.fits']

# %%
def source_name_tab(obj,compactness=False,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    if compactness:
        c = np.array([1])
    else:
        c = np.array([0])
    print (c)
    c1 = fits.Column(name='Source', array=np.array(['%s'%(obj)]), format='20A')
    c2 = fits.Column(name='Compact', array=c, format='E')
    t = fits.BinTableHDU.from_columns([c1, c2])
    t.writeto('%s/%s/%s_sourcecompactness.fits'%(destination_path_cube,obj,obj),overwrite=True)
    
def algorithm_script(obj,z,compactness,destination_path_cube="/home/mainak/Downloads/Outflow_paper1/MUSE"):
    print ('%s'%(obj))
    source_name_tab(obj,compactness)
    
z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}


compactness = {"HE0021-1810":False,"HE0021-1819":True,"HE0040-1105":True,"HE0108-4743":False,"HE0114-0015":True
    ,"HE0119-0118":False,"HE0212-0059":False,"HE0224-2834":True,"HE0227-0913":True,"HE0232-0900":False
    ,"HE0253-1641":True,"HE0345+0056":True,"HE0351+0240":False,"HE0412-0803":False,"HE0429-0247":True
    ,"HE0433-1028":False,"HE0853+0102":True,"HE0934+0119":True,"HE1011-0403":True,"HE1017-0305":True
    ,"HE1029-1831":False,"HE1107-0813":True,"HE1108-2813":True,"HE1126-0407":True,"HE1237-0504":True
    ,"HE1248-1356":False,"HE1330-1013":True,"HE1353-1917":False,"HE1417-0909":True,"HE2128-0221":True
    ,"HE2211-3903":True,"HE2222-0026":True,"HE2233+0124":True,"HE2302-0857":False}


objs = z.keys()

for obj in objs:
    algorithm_script(obj,z[obj],compactness[obj])
# Out:
# HE0021-1810
# [0]
# HE0021-1819
# [1]
# HE0040-1105
# [1]
# HE0108-4743
# [0]
# HE0114-0015
# [1]
# HE0119-0118
# [0]
# HE0212-0059
# [0]
# HE0224-2834
# [1]
# HE0227-0913
# [1]
# HE0232-0900
# [0]
# HE0253-1641
# [1]
# HE0345+0056
# [1]
# HE0351+0240
# [0]
# HE0412-0803
# [0]
# HE0429-0247
# [1]
# HE0433-1028
# [0]
# HE0853+0102
# [1]
# HE0934+0119
# [1]
# HE1011-0403
# [1]
# HE1017-0305
# [1]
# HE1029-1831
# [0]
# HE1107-0813
# [1]
# HE1108-2813
# [1]
# HE1126-0407
# [1]
# HE1237-0504
# [1]
# HE1248-1356
# [0]
# HE1330-1013
# [1]
# HE1353-1917
# [0]
# HE1417-0909
# [1]
# HE2128-0221
# [1]
# HE2211-3903
# [1]
# HE2222-0026
# [1]
# HE2233+0124
# [1]
# HE2302-0857
# [0]

# %%
def script1(obj,z,prefix_path_cube="/home/rickeythecat/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s/%s'%(prefix_path_cube,obj)

    extension = "sourcecompactness.fits"
    
    os.chdir(dir_name)

    for item in os.listdir(dir_name): # loop through items in dir
        if item.endswith(extension): 
            file_name = os.path.abspath(item) 
            copyfile(file_name,'%s/%s_sourcecompactness.fits'%(prefix_path_cube,obj))
    print ('%s'%(obj))

z = {"HE0021-1810":0.05352,"HE0021-1819":0.053197,"HE0040-1105":0.041692,"HE0108-4743":0.02392,"HE0114-0015":0.04560
    ,"HE0119-0118":0.054341,"HE0212-0059":0.026385,"HE0224-2834":0.059800,"HE0227-0913":0.016451,"HE0232-0900":0.043143
    ,"HE0253-1641":0.031588,"HE0345+0056":0.031,"HE0351+0240":0.036,"HE0412-0803":0.038160,"HE0429-0247":0.042009
    ,"HE0433-1028":0.035550,"HE0853+0102":0.052,"HE0934+0119":0.050338,"HE1011-0403":0.058314,"HE1017-0305":0.049986
    ,"HE1029-1831":0.040261,"HE1107-0813":0.058,"HE1108-2813":0.024013,"HE1126-0407":0.061960,"HE1237-0504":0.009
    ,"HE1248-1356":0.01465,"HE1330-1013":0.022145,"HE1353-1917":0.035021,"HE1417-0909":0.044,"HE2128-0221":0.05248
    ,"HE2211-3903":0.039714,"HE2222-0026":0.059114,"HE2233+0124":0.056482,"HE2302-0857":0.046860}

objs = z.keys()


for obj in objs:
    script1(obj,z[obj])

#########################################################################################   
def script2(input_filename,output_filename,destination_path_cube="/home/rickeythecat/Downloads/Outflow_paper1/MUSE"):
    dir_name = '%s'%(destination_path_cube)   
    os.chdir(dir_name)
    infiles = sorted(glob.glob(input_filename)) # './*source.fits'
    print (infiles)
    tabledict = {}
  
    for i, file in enumerate(infiles):
        hdulist = fits.open(file)
        bintab = hdulist[1].data
        table = Table(bintab)
        name = table['Source'][0]  
        tabledict[name] = table

    tab = vstack(list(tabledict.values()))
    df = tab.to_pandas()
    df = df.sort_values(by='Source', ascending=True)
    dtab = Table.from_pandas(df)
    dtab.write(output_filename, format='fits', overwrite=True)
    
script2(input_filename='./*sourcecompactness.fits',output_filename='/home/rickeythecat/Downloads/Outflow_paper1/MUSE/Big Tables/MUSE characterization outflow.fits')
# Out:
# HE0021-1810
# HE0021-1819
# HE0040-1105
# HE0108-4743
# HE0114-0015
# HE0119-0118
# HE0212-0059
# HE0224-2834
# HE0227-0913
# HE0232-0900
# HE0253-1641
# HE0345+0056
# HE0351+0240
# HE0412-0803
# HE0429-0247
# HE0433-1028
# HE0853+0102
# HE0934+0119
# HE1011-0403
# HE1017-0305
# HE1029-1831
# HE1107-0813
# HE1108-2813
# HE1126-0407
# HE1237-0504
# HE1248-1356
# HE1330-1013
# HE1353-1917
# HE1417-0909
# HE2128-0221
# HE2211-3903
# HE2222-0026
# HE2233+0124
# HE2302-0857
# ['./HE0021-1810_sourcecompactness.fits', './HE0021-1819_sourcecompactness.fits', './HE0040-1105_sourcecompactness.fits', './HE0108-4743_sourcecompactness.fits', './HE0114-0015_sourcecompactness.fits', './HE0119-0118_sourcecompactness.fits', './HE0212-0059_sourcecompactness.fits', './HE0224-2834_sourcecompactness.fits', './HE0227-0913_sourcecompactness.fits', './HE0232-0900_sourcecompactness.fits', './HE0253-1641_sourcecompactness.fits', './HE0345+0056_sourcecompactness.fits', './HE0351+0240_sourcecompactness.fits', './HE0412-0803_sourcecompactness.fits', './HE0429-0247_sourcecompactness.fits', './HE0433-1028_sourcecompactness.fits', './HE0853+0102_sourcecompactness.fits', './HE0934+0119_sourcecompactness.fits', './HE1011-0403_sourcecompactness.fits', './HE1017-0305_sourcecompactness.fits', './HE1029-1831_sourcecompactness.fits', './HE1107-0813_sourcecompactness.fits', './HE1108-2813_sourcecompactness.fits', './HE1126-0407_sourcecompactness.fits', './HE1237-0504_sourcecompactness.fits', './HE1248-1356_sourcecompactness.fits', './HE1330-1013_sourcecompactness.fits', './HE1353-1917_sourcecompactness.fits', './HE1417-0909_sourcecompactness.fits', './HE2128-0221_sourcecompactness.fits', './HE2211-3903_sourcecompactness.fits', './HE2222-0026_sourcecompactness.fits', './HE2233+0124_sourcecompactness.fits', './HE2302-0857_sourcecompactness.fits']

# %%
from astropy.table import Table, hstack

t1 = Table.read('/home/mainak/Downloads/Outflow_paper1/MUSE/Big Tables/MUSE full moffat table with errors.fits', format='fits')
t1.remove_column('Source')
t1.remove_column('Compact')
t2 = Table.read('/home/mainak/Downloads/Outflow_paper1/MUSE/MUSE characterization outflow.fits')
t2.remove_column('Source')
new = hstack([t1, t2])
new.write('/home/mainak/Downloads/Outflow_paper1/MUSE/Big Tables/MUSE full moffat table with errors.fits',overwrite=True)

# %%
t1 = Table.read('/home/mainak/Downloads/Outflow_paper1/CARS.fits')
t1.remove_column('Compact')
t2 = Table.read('/home/mainak/Downloads/Outflow_paper1/MUSE/MUSE characterization outflow.fits')
t2.remove_column('Source')
new = hstack([t1, t2])
new.write('/home/mainak/Downloads/Outflow_paper1/CARS.fits',overwrite=True)

# %%
'3 arcsec psf [OIII] br flux density.fits'

# %%
t1 = Table.read('/home/rickeythecat/Downloads/Outflow_paper1/MUSE/Big Tables/MUSE characterization outflow.fits')
t2 = Table.read('/home/rickeythecat/Downloads/Outflow_paper1/MUSE/Big Tables/3 arcsec psf [OIII] br flux density.fits')
t2.remove_column('Source')
new = hstack([t1, t2])
new.write('/home/rickeythecat/Downloads/Outflow_paper1/MUSE/Big Tables/3 arcsec psf [OIII] br flux density.fits',overwrite=True)
